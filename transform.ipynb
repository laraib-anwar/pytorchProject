# %% [markdown]
# <a href="https://colab.research.google.com/github/laraib-anwar/pytorchProject/blob/main/transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn.functional as F
from torchvision import datasets
from torchvision.transforms import v2

ds = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=v2.Compose([
        v2.ToImage(),
        v2.ToDtype(torch.float32, scale=True)
    ]),
    target_transform=v2.Lambda(
        lambda y: F.one_hot(torch.tensor(y),num_classes=10).float()
    )
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 20.3MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 305kB/s]
# 100%|██████████| 4.42M/4.42M [00:00<00:00, 4.98MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 11.0MB/s]
